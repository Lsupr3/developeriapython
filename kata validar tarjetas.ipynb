# %% [markdown]
# # "Validar Números de Tarjeta de Crédito"
#
# Descripción:
#
# Implementa una función en Python que valide si un número de tarjeta de crédito es válido utilizando el algoritmo de Luhn. Este algoritmo se utiliza para validar una variedad de números de identificación, como números de tarjeta de crédito.
#
# Requisitos:
#
# La función debe aceptar un número de tarjeta de crédito como una cadena de texto.
# Debe eliminar cualquier espacio o guiones que pueda contener.
# Debe verificar que el número contiene solo dígitos.
# Implementa el algoritmo de Luhn para determinar si el número es válido.
# **Algoritmo de Luhn**:
#
# * Desde el penúltimo dígito hacia el primero, dobla cada segundo dígito.
# * Si el resultado de la duplicación es mayor que 9, suma los dígitos del resultado.
# * Suma todos los dígitos, incluyendo aquellos que no fueron duplicados.
# * Si la suma total es divisible por 10, el número de tarjeta es válido.
#
# Ejemplo:
#
# ```python
# validate_credit_card("4539 1488 0343 6467")  # Devuelve: True
# validate_credit_card("8273 1232 7352 0569")  # Devuelve: False
# ```
#
# **Restricciones:**
#
# No utilices bibliotecas externas para la validación.
# Maneja entradas no válidas devolviendo False.

# %%
import unittest

def validate_credit_card(card_number):
    # Implementación de la función a probar
    pass

class TestValidateCreditCard(unittest.TestCase):

    def test_valid_card_number(self):
        self.assertTrue(validate_credit_card("4539 1488 0343 6467"))
        self.assertTrue(validate_credit_card("4716 2957 3594 0074"))
        self.assertTrue(validate_credit_card("6011 1111 1111 1117"))

    def test_invalid_card_number(self):
        self.assertFalse(validate_credit_card("8273 1232 7352 0569"))
        self.assertFalse(validate_credit_card("1234 5678 9101 1121"))
        self.assertFalse(validate_credit_card("0000 0000 0000 0000"))

    def test_invalid_characters(self):
        self.assertFalse(validate_credit_card("4539 1488 0343 646a"))
        self.assertFalse(validate_credit_card("6011-1111-1111-1117"))
        self.assertFalse(validate_credit_card("4716 2957 35b4 0074"))

    def test_empty_and_short_inputs(self):
        self.assertFalse(validate_credit_card(""))
        self.assertFalse(validate_credit_card("123"))
        self.assertFalse(validate_credit_card(""))

    def test_non_digit_characters(self):
        self.assertFalse(validate_credit_card("abcd efgh ijkl mnop"))
        self.assertFalse(validate_credit_card("1234-5678-90!@-1112"))
        self.assertFalse(validate_credit_card("1234 5678 90a1 112b"))

if __name__ == '__main__':
    unittest.main()
